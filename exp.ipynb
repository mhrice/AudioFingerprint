# %%
from pathlib import Path
import librosa
import numpy as np
import librosa.display
import IPython.display as ipd

# %%
root = Path("./data")

# %%
q = root / "query_recordings" / "classical.00000-snippet-10-0.wav"

# %%
d = root / "database_recordings" / "classical.00000.wav"

# %%
q1, sr1 = librosa.load(q)
d1, sr2 = librosa.load(d)

# %%
ipd.Audio(q1, rate=sr1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(d1, rate=sr2)

# %%
sr1, sr2

# %%
Q = librosa.feature.melspectrogram(y=q1, sr=sr1)

# %%
Q.shape
# Out:
# (128, 433)

# %%
q1.shape
# Out:
# (221184,)

# %%
import torch
x = torch.randn(12, 4)

# %%
y = x.T * x
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 y = x.T * x
#
# RuntimeError: The size of tensor a (10) must match the size of tensor b (2) at non-singleton dimension 1

# %%
for i in range(12):
    for j in range(12):
        a = (x[i].T * x[j]) # 1x4 -> 4x1 * 1x4 -> 4x4
        print(x.shape, x[i].T.shape, x[j].shape, a.shape)
        print(x[i].shape)
        print(a)
        break
    break
# Out:
# torch.Size([12, 4]) torch.Size([4]) torch.Size([4]) torch.Size([4])
# torch.Size([4])
# tensor([5.3545, 3.1237, 3.4552, 0.2835])

# %%
a = torch.mm(x, x.T)

# %%
a.shape
# Out:
# torch.Size([12, 12])

# %%
x[0], x[1]
# Out:
# (tensor([-2.3140, -1.7674,  1.8588,  0.5324]),
#  tensor([-0.3962,  0.0562, -0.2955,  0.8156]))

# %%
a[0][1]
# Out:
# tensor(0.7026)

# %%
a[1][0]
# Out:
# tensor(0.7026)
